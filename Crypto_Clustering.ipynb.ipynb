# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='549937cf-08a1-45b7-b829-f33f260b8bd9'>
#   <div id="d70ad2df-ead4-4703-9ed0-2ca488253185" data-root-id="549937cf-08a1-45b7-b829-f33f260b8bd9" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the data into a Pandas DataFrame
df_market_data = pd.read_csv(
    "Resources/crypto_market_data.csv",
    index_col="coin_id")

# Display sample data
df_market_data.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
df_market_data.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
# Plot your data to see what's in your DataFrame
df_market_data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [coin_id]   (value)

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_market_data)

# %%
# Create a DataFrame with the scaled data
df_scaled = pd.DataFrame(
    scaled_data,
    columns=df_market_data.columns
)

# Copy the crypto names from the original DataFrame
df_scaled["coin_id"] = df_market_data.index

# Set the coin_id column as index
df_scaled = df_scaled.set_index("coin_id")

# Display the scaled DataFrame
df_scaled.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Scaled DataFrame.

# %%
# Create a list with the number of k-values from 1 to 11
k_original = list(range(1, 11))

# %%
# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
for i in k_original:
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
    model_original = KMeans(n_clusters=i, random_state=1)
# 2. Fit the model to the data using `df_market_data_scaled`
    model_original.fit(df_scaled)
# 3. Append the model.inertia_ to the inertia list
    inertia.append(model_original.inertia_)
# Out:
# c:\Users\jenn2\anaconda3\envs\PythonData\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\jenn2\anaconda3\envs\PythonData\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\jenn2\anaconda3\envs\PythonData\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data_original = {
    "k": k_original,
    "inertia": inertia
}


# Create a DataFrame with the data to plot the Elbow curve
df_elbow_original = pd.DataFrame(elbow_data_original)

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.
df_elbow.hvplot.line(
    x="k", 
    y="inertia", 
    title="Elbow Curve", 
    xticks=k_values
)
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the best value for `k`?
#
# **Answer:** 4

# %% [markdown]
# ---

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Scaled DataFrame

# %%
# Initialize the K-Means model using the best value for k
model = KMeans(n_clusters=4)

# %%
# Fit the K-Means model using the scaled DataFrame
model.fit(df_scaled)
# Out:
# c:\Users\jenn2\anaconda3\envs\PythonData\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled DataFrame
clusters = model.predict(df_scaled)

# Print the resulting array of cluster values.
print(clusters)
# Out:
# [3 3 0 0 3 3 3 3 3 0 0 0 0 3 0 3 0 0 3 0 0 3 0 0 0 0 0 0 3 0 0 0 1 3 0 0 2
#  0 0 0 0]

# %%
# Create a copy of the scaled DataFrame
df_scaled_predictions = df_scaled.copy()

# %%
# Add a new column to the copy of the scaled DataFrame with the predicted clusters
df_scaled_predictions["Clusters"] = clusters

# Display the copy of the scaled DataFrame
df_scaled_predictions.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
# Create a scatter plot using hvPlot by setting
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`.
# Color the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.
df_scaled_predictions.hvplot.scatter(
    x="price_change_percentage_24h",
    y="price_change_percentage_7d",
    c="Clusters",
    hover_cols=["coin_id"]
)
# Out:
# :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,Clusters,coin_id)

# %% [markdown]
# ---

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` to reduce the original scaled DataFrame
# down to three principal components.
pca_data = pca.fit_transform(df_scaled)

# View the scaled PCA data
pca_data
# Out:
# array([[-0.60066733,  0.84276006,  0.46159457],
#        [-0.45826071,  0.45846566,  0.95287678],
#        [-0.43306981, -0.16812638, -0.64175193],
#        [-0.47183495, -0.22266008, -0.47905316],
#        [-1.15779997,  2.04120919,  1.85971527],
#        [-0.51653377,  1.38837748,  0.80407131],
#        [-0.45071134,  0.51769912,  2.84614316],
#        [-0.34559977,  0.72943939,  1.47801284],
#        [-0.64946792,  0.43216514,  0.60030286],
#        [-0.75901394, -0.20119979, -0.21765292],
#        [-0.24819846, -1.37625159, -1.46202571],
#        [-0.43840762, -0.17533654, -0.6633884 ],
#        [-0.69342533, -0.47381462, -0.52759693],
#        [ 0.06049915,  2.90940385,  1.49857131],
#        [-0.39335243, -0.10819197, -0.01275608],
#        [-0.79617564, -0.49440875,  1.08281169],
#        [ 0.06407452, -1.26982514, -1.09882928],
#        [-0.48901506, -0.73271912, -0.06254323],
#        [-0.3062723 ,  0.70341515,  1.71422359],
#        [-0.51352775, -0.14280239, -0.65656583],
# ...

# %%
# Retrieve the explained variance to determine how much information
# can be attributed to each principal component.
explained_variance = pca.explained_variance_ratio_

print("Explained Variance Ratio:")
for i, variance in enumerate(explained_variance, start=1):
    print(f"PC{i}: {variance:.4f}")
# Out:
# Explained Variance Ratio:
# PC1: 0.3720
# PC2: 0.3470
# PC3: 0.1760

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:** Total Explained Variance = 0.3720 + 0.3470 + 0.1760 = 0.8950 = 89.5%

# %%
# Create a new DataFrame with the PCA data.
df_pca = pd.DataFrame(
    pca_data,
    columns=["PC1", "PC2", "PC3"]
)

# Copy the crypto names from the original scaled DataFrame
df_pca["coin_id"] = df_scaled.index

# Set the coin_id column as index
df_pca = df_pca.set_index("coin_id")

# Display the scaled PCA DataFrame
df_pca.head()
# Out:
#                    PC1       PC2       PC3
# coin_id
# bitcoin      -0.600667  0.842760  0.461595
# ethereum     -0.458261  0.458466  0.952877
# tether       -0.433070 -0.168126 -0.641752
# ripple       -0.471835 -0.222660 -0.479053
# bitcoin-cash -1.157800  2.041209  1.859715

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Scaled PCA DataFrame

# %%
# Create a list with the number of k-values from 1 to 11
k = list(range(1,11))

# %%
# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
for i in k:
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
    model = KMeans(n_clusters=i, random_state=1)
# 2. Fit the model to the data using `df_market_data_pca`
    model.fit(df_pca)
# 3. Append the model.inertia_ to the inertia list
    inertia.append(model.inertia_)
# Out:
# c:\Users\jenn2\anaconda3\envs\PythonData\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\jenn2\anaconda3\envs\PythonData\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\jenn2\anaconda3\envs\PythonData\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data_pca = {
    "k": k,
    "inertia": inertia
}
# Create a DataFrame with the data to plot the Elbow curve
df_elbow_pca = pd.DataFrame(elbow_data_pca)

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.
df_elbow_pca.hvplot.line(
    x="k", 
    y="inertia", 
    title="Elbow Curve (PCA)", 
    xticks=k
)
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following questions:
#
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** Still 4
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** Although the inertia values are slightly different, the overall shape of the graph is generally the same, with the ideal value for k still being 4.

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Scaled PCA DataFrame

# %%
# Initialize the K-Means model using the best value for k
model = KMeans(n_clusters=4)

# %%
# Fit the K-Means model using the PCA data
model.fit(df_pca)
# Out:
# c:\Users\jenn2\anaconda3\envs\PythonData\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled PCA DataFrame
pca_clusters = model.predict(df_pca)

# Print the resulting array of cluster values.
print(pca_clusters)
# Out:
# [3 3 0 0 3 3 3 3 3 0 0 0 0 3 0 3 0 0 3 0 0 3 0 0 0 0 0 0 3 0 0 0 1 3 0 0 2
#  0 0 0 0]

# %%
# Create a copy of the scaled PCA DataFrame
df_pca_clustered = df_pca.copy()

# Add a new column to the copy of the PCA DataFrame with the predicted clusters
df_pca_clustered["Clusters"] = pca_clusters

# Display the copy of the scaled PCA DataFrame
df_pca_clustered.head()
# Out:
#                    PC1       PC2       PC3  Clusters
# coin_id
# bitcoin      -0.600667  0.842760  0.461595         3
# ethereum     -0.458261  0.458466  0.952877         3
# tether       -0.433070 -0.168126 -0.641752         0
# ripple       -0.471835 -0.222660 -0.479053         0
# bitcoin-cash -1.157800  2.041209  1.859715         3

# %%
# Create a scatter plot using hvPlot by setting
# `x="PC1"` and `y="PC2"`.
# Color the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.
df_pca_clustered.hvplot.scatter(
    x="PC1",
    y="PC2",
    c="Clusters",
    hover_cols=["coin_id"]
)
# Out:
# :Scatter   [PC1]   (PC2,Clusters,coin_id)

# %% [markdown]
# ### Visualize and Compare the Results
#
# In this section, you will visually analyze the cluster analysis results by contrasting the outcome with and without using the optimization techniques.

# %%
#pip install jupyter_bokeh
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df_elbow["k"] = df_elbow["k"].astype(int)
df_elbow_pca["k"] = df_elbow_pca["k"].astype(int)

# %%
# Composite plot to contrast the Elbow curves
df_elbow["Source"] = "Original"
df_elbow_pca["Source"] = "PCA Reduced"
df_elbow_combined = pd.concat([df_elbow, df_elbow_pca])
df_elbow_combined.hvplot.line(
    x="k",
    y="inertia",
    by="Source",
    title="Elbow Curve Comparison: Original vs PCA-Reduced Data",
    xlabel="Number of Clusters (k)",
    ylabel="Inertia",
    xticks=list(range(1, 11))
)
# Out:
# :NdOverlay   [Source]
#    :Curve   [k]   (inertia)

# %%
# Composite plot to contrast the clusters
df_original_clusters = df_scaled.copy()
df_original_clusters["Cluster"] = model.predict(df_scaled)
df_original_clusters["Source"] = "Original"
df_original_clusters["PC1"] = df_pca["PC1"]
df_original_clusters["PC2"] = df_pca["PC2"]

# PCA clustering results
df_pca_clustered = df_pca.copy()
df_pca_clustered["Cluster"] = model.predict(df_pca)
df_pca_clustered["Source"] = "PCA Reduced"

# Combine both DataFrames for comparison
df_cluster_comparison = pd.concat([df_original_clusters, df_pca_clustered], ignore_index=True)


df_cluster_comparison.hvplot.scatter(
    x="PC1",
    y="PC2",
    groupby="Source",
    c="Cluster",
    hover_cols=["coin_id"],
    title="Comparison of Clusters: Original vs PCA-Reduced Data"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 3
#       1 # Composite plot to contrast the clusters
#       2 df_original_clusters = df_scaled.copy()
# ----> 3 df_original_clusters["Cluster"] = model.predict(df_scaled)
#       4 df_original_clusters["Source"] = "Original"
#       5 df_original_clusters["PC1"] = df_pca["PC1"]
#
# File c:\Users\jenn2\anaconda3\envs\PythonData\lib\site-packages\sklearn\cluster\_kmeans.py:1091, in _BaseKMeans.predict(self, X)
#    1073 """Predict the closest cluster each sample in X belongs to.
#    1074
#    1075 In the vector quantization literature, `cluster_centers_` is called
#    (...)
#    1087     Index of the cluster each sample belongs to.
#    1088 """
#    1089 check_is_fitted(self)
# -> 1091 X = self._check_test_data(X)
#    1093 # sample weights are not used by predict but cython helpers expect an array
# ...

# %%
# Create and fit a new KMeans model on PCA-reduced data
pca_kmeans = KMeans(n_clusters=4, random_state=1)
pca_kmeans.fit(df_pca)

# Predict clusters based on PCA data
df_pca_clustered = df_pca.copy()
df_pca_clustered["Cluster"] = pca_kmeans.predict(df_pca)
df_pca_clustered["Source"] = "PCA Reduced"

df_original_clusters = df_scaled.copy()
df_original_clusters["Cluster"] = model.predict(df_scaled)
df_original_clusters["Source"] = "Original"
df_original_clusters["PC1"] = df_pca["PC1"]
df_original_clusters["PC2"] = df_pca["PC2"]

df_cluster_comparison = pd.concat([df_original_clusters, df_pca_clustered], ignore_index=True)

# Plot composite cluster comparison
df_cluster_comparison.hvplot.scatter(
    x="PC1",
    y="PC2",
    groupby="Source",
    c="Cluster",
    cmap="Category10",
    hover_cols=["coin_id"],
    title="Cluster Comparison: Original vs PCA-Reduced"
)
# Out:
# c:\Users\jenn2\anaconda3\envs\PythonData\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 11
#       8 df_pca_clustered["Source"] = "PCA Reduced"
#      10 df_original_clusters = df_scaled.copy()
# ---> 11 df_original_clusters["Cluster"] = model.predict(df_scaled)
#      12 df_original_clusters["Source"] = "Original"
#      13 df_original_clusters["PC1"] = df_pca["PC1"]
#
# File c:\Users\jenn2\anaconda3\envs\PythonData\lib\site-packages\sklearn\cluster\_kmeans.py:1091, in _BaseKMeans.predict(self, X)
#    1073 """Predict the closest cluster each sample in X belongs to.
#    1074
# ...

# %% [markdown]
# #### Answer the following question:
#
#   * **Question:** After visually analyzing the cluster analysis results, what is the impact of using fewer features to cluster the data using K-Means?
#
#   * **Answer:**
